# %% [markdown]
# # 00 Check Setup
#
# Smoke check for imports, device selection, and AG News loading.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / "src"))

from text_distillation.data import load_ag_news, make_tiny_subset
from text_distillation.utils import get_device, set_seed

# %%
SEED = 42
DATASET_NAME = "ag_news"
TEXT_COLUMN = "text"
LABEL_COLUMN = "label"
TINY_N_PER_CLASS = 2

set_seed(SEED)
print("device:", get_device())
# Out:
# device: cpu

# %%
dataset = load_ag_news()
train_dataset = dataset["train"]
test_dataset = dataset["test"]

tiny_train = make_tiny_subset(train_dataset, n_per_class=TINY_N_PER_CLASS, seed=SEED)
print(dataset)
print(tiny_train[:3])
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 120000
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 7600
#     })
# })
# {'text': ['Thatcher son was planning to flee Mark Thatcher, multi-millionaire businessman and son of former British prime minister Margaret Thatcher, had planned to flee South Africa shortly before he was arrested on charges of being involved in a coup plot to overthrow the government of the central ', 'Cricket: India fights Ganguly ban Sourav Ganguly files an appeal against a two-match ban imposed for time-wasting.', 'Tiger needs focus It #39;s doubtful that Elin Nordegren, retired swimsuit model and nanny, ever aspired to the title  quot;Most Powerful Person in Golf.'], 'label': [0, 0, 1]}
